# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
from mpl_toolkits.mplot3d import Axes3D # <--- This is important for 3d plotting 


# Import datasets, classifiers and performance metrics
from sklearn import datasets, svm, metrics
import numpy.random as npr
import numpy as np
import seaborn as sns
sns.set_style("white")

color_names = ["black",
               "windows blue",
               "red",
               "amber",
               "faded green",
               "dusty purple",
               "orange",
               "clay",
               "pink",
               "greyish",
               "mint",
               "light cyan",
               "steel blue",
               "forest green",
               "pastel purple",
               "salmon",
               "dark brown"]

colors = sns.xkcd_palette(color_names)

# %%
digits = datasets.load_digits()

# _, axes = plt.subplots(nrows=1, ncols=4, figsize=(10, 3))
# for ax, image, label in zip(axes, digits.images, digits.target):
#     ax.set_axis_off()
#     ax.imshow(image, cmap=plt.cm.gray_r, interpolation='nearest')
#     ax.set_title('Training: %i' % label)

# %%
digits.target
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
dat_digits = digits.images.reshape(digits.images.shape[0],-1)

# %%
# choose 3 pixels
# selected_pixelstart = npr.choice(dat_digits.shape[1]-2, 1)
selected_pixelstart = 14
selected_pixels = np.array([selected_pixelstart,selected_pixelstart+1,selected_pixelstart+2])
print(selected_pixels)
fig = plt.figure(figsize=(5,5))
ax = plt.axes(projection='3d')
scatter = ax.scatter3D(dat_digits[:,selected_pixels[0]], \
                    dat_digits[:,selected_pixels[1]], \
                    dat_digits[:,selected_pixels[2]], \
                    color = colors[-2], \
                    linewidth=0, antialiased=False)
ax.set_xlabel('Pixel ' + str(selected_pixels[0]))
ax.set_ylabel('Pixel ' + str(selected_pixels[1]))
ax.set_zlabel('Pixel ' + str(selected_pixels[2]))
plt.tight_layout()
# plt.legend()
plt.savefig("mnist_pixel_" + str(selected_pixels[0]) + ".pdf", bbox_inches='tight')
# Out:
# [14 15 16]

# %%
# choose 3 pixels
# selected_pixelstart = npr.choice(dat_digits.shape[1]-2, 1)
selected_pixelstart = 0
selected_pixels = np.array([selected_pixelstart,selected_pixelstart+1,selected_pixelstart+2])
print(selected_pixels)
fig = plt.figure(figsize=(5,5))
ax = plt.axes(projection='3d')
scatter = ax.scatter3D(dat_digits[:,selected_pixels[0]], \
                    dat_digits[:,selected_pixels[1]], \
                    dat_digits[:,selected_pixels[2]], \
                    color = colors[-2], \
                    linewidth=0, antialiased=False)
ax.set_xlabel('Pixel ' + str(selected_pixels[0]))
ax.set_ylabel('Pixel ' + str(selected_pixels[1]))
ax.set_zlabel('Pixel ' + str(selected_pixels[2]))
plt.tight_layout()
# plt.legend()
plt.savefig("mnist_pixel_" + str(selected_pixels[0]) + ".pdf", bbox_inches='tight')
# Out:
# [0 1 2]

# %%
# choose 3 pixels
# selected_pixelstart = npr.choice(dat_digits.shape[1]-2, 1)
selected_pixelstart = 45
selected_pixels = np.array([selected_pixelstart,selected_pixelstart+1,selected_pixelstart+2])
print(selected_pixels)
fig = plt.figure(figsize=(5,5))
ax = plt.axes(projection='3d')
scatter = ax.scatter3D(dat_digits[:,selected_pixels[0]], \
                    dat_digits[:,selected_pixels[1]], \
                    dat_digits[:,selected_pixels[2]], \
                    color = colors[-2], \
                    linewidth=0, antialiased=False)
ax.set_xlabel('Pixel ' + str(selected_pixels[0]))
ax.set_ylabel('Pixel ' + str(selected_pixels[1]))
ax.set_zlabel('Pixel ' + str(selected_pixels[2]))
plt.tight_layout()
# plt.legend()
plt.savefig("mnist_pixel_" + str(selected_pixels[0]) + ".pdf", bbox_inches='tight')
# Out:
# [45 46 47]

# %%
# choose 3 pixels
# selected_pixelstart = npr.choice(dat_digits.shape[1]-2, 1)
selected_pixelstart = 56
selected_pixels = np.array([selected_pixelstart,selected_pixelstart+1,selected_pixelstart+2])
print(selected_pixels)
fig = plt.figure(figsize=(5,5))
ax = plt.axes(projection='3d')
scatter = ax.scatter3D(dat_digits[:,selected_pixels[0]], \
                    dat_digits[:,selected_pixels[1]], \
                    dat_digits[:,selected_pixels[2]], \
                    color = colors[-2], \
                    linewidth=0, antialiased=False)
ax.set_xlabel('Pixel ' + str(selected_pixels[0]))
ax.set_ylabel('Pixel ' + str(selected_pixels[1]))
ax.set_zlabel('Pixel ' + str(selected_pixels[2]))
plt.tight_layout()
# plt.legend()
plt.savefig("mnist_pixel_" + str(selected_pixels[0]) + ".pdf", bbox_inches='tight')
# Out:
# [56 57 58]

# %%
# choose 3 pixels
selected_pixelstart = npr.choice(dat_digits.shape[1]-2, 1)[0]
# selected_pixelstart = 32
selected_pixels = np.array([selected_pixelstart,selected_pixelstart+1,selected_pixelstart+2])
print(selected_pixels)
fig = plt.figure(figsize=(5,5))
ax = plt.axes(projection='3d')
scatter = ax.scatter3D(dat_digits[:,selected_pixels[0]], \
                    dat_digits[:,selected_pixels[1]], \
                    dat_digits[:,selected_pixels[2]], \
                    color = colors[-2], \
                    linewidth=0, antialiased=False)
ax.set_xlabel('Pixel ' + str(selected_pixels[0]))
ax.set_ylabel('Pixel ' + str(selected_pixels[1]))
ax.set_zlabel('Pixel ' + str(selected_pixels[2]))
plt.tight_layout()
# plt.legend()
plt.savefig("mnist_pixel_" + str(selected_pixels[0]) + ".pdf", bbox_inches='tight')
# Out:
# [4 5 6]

# %%
from sklearn.datasets import load_wine
wine = load_wine()

# %%
dat_wine = wine['data']

# %%
# choose 3 pixels
# selected_pixelstart = npr.choice(dat_wine.shape[1]-2, 1)[0]
selected_pixelstart = 5
selected_pixels = np.array([selected_pixelstart,selected_pixelstart+1,selected_pixelstart+2])
print(selected_pixels)
fig = plt.figure(figsize=(5,5))
ax = plt.axes(projection='3d')
scatter = ax.scatter3D(dat_wine[:,selected_pixels[0]], \
                    dat_wine[:,selected_pixels[1]], \
                    dat_wine[:,selected_pixels[2]], \
                    color = colors[-2], \
                    linewidth=0, antialiased=False)
ax.set_xlabel(wine.feature_names[selected_pixels[0]])
ax.set_ylabel(wine.feature_names[selected_pixels[1]])
ax.set_zlabel(wine.feature_names[selected_pixels[2]])
plt.tight_layout()
# plt.legend()
plt.savefig("wine_" + str(selected_pixels[0]) + ".pdf", bbox_inches='tight')
# Out:
# [5 6 7]

# %%
# code comes from https://stackabuse.com/python-for-nlp-sentiment-analysis-with-scikit-learn/
import pandas as pd
# data_source_url = "https://raw.githubusercontent.com/kolaveridi/kaggle-Twitter-US-Airline-Sentiment-/master/Tweets.csv"
data_source_url = "https://raw.githubusercontent.com/satyajeetkrjha/kaggle-Twitter-US-Airline-Sentiment-/master/Tweets.csv"
airline_tweets = pd.read_csv(data_source_url)

# %%
airline_tweets.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# ...

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer


features = airline_tweets.iloc[:, 10].values
processed_features = []

for sentence in range(0, len(features)):
    # Remove all the special characters
    processed_feature = re.sub(r'\W', ' ', str(features[sentence]))

    # remove all single characters
    processed_feature= re.sub(r'\s+[a-zA-Z]\s+', ' ', processed_feature)

    # Remove single characters from the start
    processed_feature = re.sub(r'\^[a-zA-Z]\s+', ' ', processed_feature) 

    # Substituting multiple spaces with single space
    processed_feature = re.sub(r'\s+', ' ', processed_feature, flags=re.I)

    # Removing prefixed 'b'
    processed_feature = re.sub(r'^b\s+', '', processed_feature)

    # Converting to Lowercase
    processed_feature = processed_feature.lower()

    processed_features.append(processed_feature)

    
vectorizer = TfidfVectorizer (max_features=500, min_df=20, max_df=0.8, stop_words=stopwords.words('english'))
processed_features = vectorizer.fit_transform(processed_features).toarray()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/yuenc2/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# choose 3 words
# selected_words = npr.choice(dat_digits.shape[1], 3, replace=False)
# selected_wordstart = npr.choice(dat_digits.shape[1]-2, 1, replace=False)[0]
selected_wordstart = 24
selected_words = np.array([selected_wordstart,selected_wordstart+1,selected_wordstart+2])
print(selected_words)
# Out:
# [24 25 26]

# %%
fig = plt.figure(figsize=(5,5))
ax = plt.axes(projection='3d')
scatter = ax.scatter3D(dat_digits[:,selected_words[0]], \
                    dat_digits[:,selected_words[1]], \
                    dat_digits[:,selected_words[2]], \
                    color = colors[-2], \
                    linewidth=0, antialiased=False)
ax.set_xlabel('word ' + str(selected_words[0]) + ": '" + vectorizer.get_feature_names_out()[selected_words[0]] + "'")
ax.set_ylabel('word ' + str(selected_words[1]) + ": '" + vectorizer.get_feature_names_out()[selected_words[1]] + "'")
ax.set_zlabel('word ' + str(selected_words[2]) + ": '" + vectorizer.get_feature_names_out()[selected_words[2]] + "'")
plt.tight_layout()
# plt.legend()
plt.savefig("tweet_word_" + str(selected_words[0]) + ".pdf", bbox_inches='tight')
